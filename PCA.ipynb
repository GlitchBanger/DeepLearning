# %%
import pandas as pd
from sklearn.decomposition import PCA

# %%
dataset = pd.read_csv('./diabetes.csv')
dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
analyzer = PCA(n_components = 3)

# %%
dataset.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
reduced_data = analyzer.fit_transform(dataset[dataset.columns].to_numpy())

# %%
reduced_data
# Out:
# array([[-75.71424916, -35.95494354,  -7.26068338],
#        [-82.35846646,  28.90955895,  -5.49664901],
#        [-74.63022933, -67.90963328,  19.46175322],
#        ...,
#        [ 32.11298721,   3.37922193,  -1.58797191],
#        [-80.21409513, -14.19059537,  12.35142227],
#        [-81.30834662,  21.6230423 ,  -8.15277416]])

# %%
dataset.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
pd.DataFrame(analyzer.get_covariance())
# Out:
#            0            1           2           3             4           5  \
# 0  61.458859    15.490247    9.201081   -0.513662    -28.920785    1.529629
# 1  15.490247  1019.915318   97.752076   16.037838   1222.009351   51.918871
# 2   9.201081    97.752076  362.450407   99.337523    196.003024   49.125343
# 3  -0.513662    16.037838   99.337523  144.242653    810.926627   22.442928
# 4 -28.920785  1222.009351  196.003024  810.926627  13280.590409  181.600605
# 5   1.529629    51.918871   49.125343   22.442928    181.600605   71.129310
# 6   0.006328     1.366118    0.411579    0.460774      7.074387    0.162237
# 7   3.794481   108.224669   54.741531    2.729189    -59.857049   10.552587
# 8   0.120319     6.724655    0.899543    0.091388      7.210539    0.383525
#
#            6           7          8
# 0   0.006328    3.794481   0.120319
# 1   1.366118  108.224669   6.724655
# 2   0.411579   54.741531   0.899543
# 3   0.460774    2.729189   0.091388
# ...

# %%
analyzer.explained_variance_ratio_
# Out:
# array([0.88853359, 0.06159289, 0.02578973])
